# %%
import time

import pandas as pd
import requests
from tqdm import tqdm
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def holidays_api_call(props, url = "https://holidays.abstractapi.com/v1/"):
    country = props['country']
    year = props['year']
    month = props['month']
    day = props['day']

    response = requests.get(url, params={
        "api_key": "5a266c12bafb4680a128f4f9c44f450e",
        "country": country,
        "year": year,
        "month": month,
        "day": day
    })
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"API call failed with status code {response.status_code}")

# %%
df = pd.read_csv('/Users/ziadsamer/Documents/who-will-viral/data/youtube/youtube.csv')
# Out:
# /var/folders/p6/82pzwvfj08b5bktj5wbwqwh00000gn/T/ipykernel_22075/2405818914.py:1: DtypeWarning: Columns (0: trending_date) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/ziadsamer/Documents/who-will-viral/data/youtube/youtube.csv')

# %%
df
# Out:
#            video_id                                              title  \
# 0       G4M_621v1As       college farewell video#trending #viralshorts
# 1       z2voqo_Jhx4  Busking in Manchester 🇬🇧 #blindfaith #guitar #...
# 2       jHIt9oHFLsw  This is what happens when you play Star Wars i...
# 3       gwRqLbWqKlM  LISA - FUTW (YouTube Music Nights Special Stag...
# 4       prpRoyrutcE        Uljhi hai yeh kis jaal me tu…. Bengaluru ❤️
# ...             ...                                                ...
# 390038  qUXdVB2wPGw  Haz que tu XIAOMI parezca un iPhone #urbantecn...
# 390039  dUpyC40cF6Q  Reading in Files in Pandas | Python Pandas Tut...
# 390040  PtLgQCMaASM  Gatitos Squishy de papel muy fáciles - antiest...
# 390041  Is4n5yN1wzs  📱S23 / S25 ULTRA EXPERT RAW - TUTORIAL PASO A ...
# 390042  2sc-_U1qZXk  Glue Song - beabadoobee Beginner Guitar Lesson...
#
#                  publishedAt                 channelId      channelTitle  \
# 0       2025-04-12T02:06:42Z  UC7k_7IF3s3TY-cowwxs_yWw       Vk_07_rider
# 1       2025-04-06T11:35:53Z  UCM_9JHB3xXPSzJfTkD86AtA  Leonardo Patrick
# 2       2025-04-06T10:07:12Z  UC4YyKY5o60Kckk-GXOnhT2g     Violin Phonix
# 3       2025-03-19T03:29:33Z  UC6-BgjsBa5R3PZQ_kZ8hKPg    LLOUD Official
# 4       2025-04-14T10:17:58Z  UCiFXnvi8ESDukE25ol2foWQ         Mr.KiranJ
# ...                      ...                       ...               ...
# 390038  2023-03-03T15:44:15Z  UCHhfu5p0zydyM-_nw3IJvig       Urban Tecno
# 390039  2023-02-28T12:30:18Z  UC7cs8q-gJRlGwj4A8OmCmXg  Alex The Analyst
# 390040  2023-03-02T18:00:19Z  UCpqIW0f1XZJrNQTzE-6IjBw          RaniArts
# 390041  2023-02-23T17:00:21Z  UCZmPpmweoSmxFKQTn8lVHCw      Iván Ferrero
# 390042  2023-02-18T13:00:02Z  UCFifQL1z9qnVdIq-EVDU9FQ   for3v3rfaithful
#
#         categoryId trending_date  \
# 0             22.0    2025-11-08
# 1             10.0    2025-11-08
# 2             22.0    2025-11-08
# 3             10.0    2025-11-08
# 4             10.0    2025-11-08
# ...            ...           ...
# 390038        28.0           NaN
# 390039        27.0           NaN
# 390040        24.0           NaN
# 390041        27.0           NaN
# 390042        10.0           NaN
#
#                                                      tags   view_count  \
# 0       college farewell video, DDU farewell video, fa...  125784084.0
# 1                                                     NaN   94744011.0
# 2                                                     NaN   61945818.0
# 3       Blackpink, Lisa, Music, Fashion, K-Pop, kpop, ...   14555963.0
# 4                                                     NaN   26204942.0
# ...                                                   ...          ...
# 390038                                                NaN     489410.0
# 390039  Data Analyst, Data Analyst job, Data Analyst C...     279703.0
# 390040  diy, paper, squishy, squishies, paper cat, gat...     744928.0
# 390041  EXPERT RAW, S23 ULTRA, S23 ULTRA PHOTOGRAPHY, ...     656501.0
# 390042                                   #for3v3rfaithful     196230.0
#
#             likes  comment_count  \
# 0       1557178.0         1583.0
# 1        925529.0         5849.0
# 2       1067412.0         4124.0
# 3        455816.0        20396.0
# 4        336267.0         2333.0
# ...           ...            ...
# 390038    16687.0          146.0
# 390039     4470.0          128.0
# 390040    23062.0          163.0
# 390041    30226.0          949.0
# 390042     4916.0           83.0
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/G4M_621v1As/default.jpg                  0
# 1       https://i.ytimg.com/vi/z2voqo_Jhx4/default.jpg                  0
# 2       https://i.ytimg.com/vi/jHIt9oHFLsw/default.jpg                  0
# 3       https://i.ytimg.com/vi/gwRqLbWqKlM/default.jpg                  0
# 4       https://i.ytimg.com/vi/prpRoyrutcE/default.jpg                  0
# ...                                                ...                ...
# 390038  https://i.ytimg.com/vi/qUXdVB2wPGw/default.jpg                  0
# 390039  https://i.ytimg.com/vi/dUpyC40cF6Q/default.jpg                  0
# 390040  https://i.ytimg.com/vi/PtLgQCMaASM/default.jpg                  0
# 390041  https://i.ytimg.com/vi/Is4n5yN1wzs/default.jpg                  0
# 390042  https://i.ytimg.com/vi/2sc-_U1qZXk/default.jpg                  0
#
#                                               description  is_trending
# 0       DDU farewell party video \n college farewell v...            1
# 1                                                     NaN            1
# 2       Full video : https://www.youtube.com/watch?v=Q...            1
# 3       LISA’s debut album, ‘Alter Ego’ is out now. Li...            1
# 4                                                     NaN            1
# ...                                                   ...          ...
# 390038                                                NaN            0
# 390039  Take my Full Python Course Here: https://www.a...            0
# 390040  Hola RaniArtistas, en este vídeo les enseño có...            0
# 390041  Expert RAW explicado a fondo por un FOTÓGRAFO....            0
# 390042  Get my printable guitar guide for this song! 🖨...            0
#
# [390043 rows x 15 columns]

# %%
all_dates = df['eventdate'].value_counts().sort_index().keys().tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/who-will-viral/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'eventdate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 all_dates = df['eventdate'].value_counts().sort_index().keys().tolist()
#
# File ~/Documents/who-will-viral/.venv/lib/python3.14/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/Documents/who-will-viral/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'eventdate'

# %%
all_dates_dict = {}
all_dates_country = {}

# %%
curr_country = "RU"

# %%
for date in tqdm(all_dates):
    if (date, curr_country) not in all_dates_country:
        curr_date = pd.to_datetime(date, format='%Y-%m-%d')
        curr_year = curr_date.year
        curr_month = curr_date.month if curr_date.month >= 10 else f"0{curr_date.month}"
        curr_day = curr_date.day if curr_date.day >= 10 else f"0{curr_date.day}"
        try:
            all_dates_country[(date, curr_country)] = holidays_api_call(props = {
                'year': str(curr_year),
                'month': str(curr_month),
                'day': str(curr_day),
                'country': curr_country
            })
            time.sleep(1)
        except Exception as e:
            print(f"Error for date {date}: {e}")
# Out:
# 100%|██████████| 151/151 [04:38<00:00,  1.84s/it]

# %%
all_dates_country
# Out:
# {('2016-01-01',
#   'IT'): [{'name': "New Year's Day",
#    'name_local': "New Year's Day",
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '01/01/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '01',
#    'week_day': 'Friday'}],
#  ('2016-01-02', 'IT'): [],
#  ('2016-01-03', 'IT'): [],
#  ('2016-01-04', 'IT'): [],
#  ('2016-01-05', 'IT'): [],
#  ('2016-01-06',
#   'IT'): [{'name': 'Epiphany',
#    'name_local': 'Epiphany',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '01/06/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '06',
#    'week_day': 'Wednesday'}],
#  ('2016-01-07', 'IT'): [],
#  ('2016-01-08', 'IT'): [],
#  ('2016-01-09', 'IT'): [],
#  ('2016-01-10', 'IT'): [],
#  ('2016-01-11', 'IT'): [],
#  ('2016-01-12', 'IT'): [],
#  ('2016-01-13', 'IT'): [],
#  ('2016-01-14', 'IT'): [],
#  ('2016-01-15', 'IT'): [],
#  ('2016-01-16', 'IT'): [],
#  ('2016-01-17', 'IT'): [],
#  ('2016-01-18', 'IT'): [],
#  ('2016-01-19', 'IT'): [],
#  ('2016-01-20', 'IT'): [],
#  ('2016-01-21', 'IT'): [],
#  ('2016-01-22', 'IT'): [],
#  ('2016-01-23', 'IT'): [],
#  ('2016-01-24', 'IT'): [],
#  ('2016-01-25', 'IT'): [],
#  ('2016-01-26', 'IT'): [],
#  ('2016-01-27', 'IT'): [],
#  ('2016-01-28', 'IT'): [],
#  ('2016-01-29', 'IT'): [],
#  ('2016-01-30', 'IT'): [],
#  ('2016-01-31', 'IT'): [],
#  ('2016-02-01', 'IT'): [],
#  ('2016-02-02', 'IT'): [],
#  ('2016-02-03', 'IT'): [],
#  ('2016-02-04', 'IT'): [],
#  ('2016-02-05', 'IT'): [],
#  ('2016-02-06', 'IT'): [],
#  ('2016-02-07', 'IT'): [],
#  ('2016-02-08', 'IT'): [],
#  ('2016-02-09', 'IT'): [],
#  ('2016-02-10', 'IT'): [],
#  ('2016-02-11', 'IT'): [],
#  ('2016-02-12', 'IT'): [],
#  ('2016-02-13', 'IT'): [],
#  ('2016-02-14', 'IT'): [],
#  ('2016-02-15', 'IT'): [],
#  ('2016-02-16', 'IT'): [],
#  ('2016-02-17', 'IT'): [],
#  ('2016-02-18', 'IT'): [],
#  ('2016-02-19', 'IT'): [],
#  ('2016-02-20', 'IT'): [],
#  ('2016-02-21', 'IT'): [],
#  ('2016-02-22', 'IT'): [],
#  ('2016-02-23', 'IT'): [],
#  ('2016-02-24', 'IT'): [],
#  ('2016-02-25', 'IT'): [],
#  ('2016-02-26', 'IT'): [],
#  ('2016-02-27', 'IT'): [],
#  ('2016-02-28', 'IT'): [],
#  ('2016-02-29', 'IT'): [],
#  ('2016-03-01', 'IT'): [],
#  ('2016-03-02', 'IT'): [],
#  ('2016-03-03', 'IT'): [],
#  ('2016-03-04', 'IT'): [],
#  ('2016-03-05', 'IT'): [],
#  ('2016-03-06', 'IT'): [],
#  ('2016-03-07', 'IT'): [],
#  ('2016-03-08', 'IT'): [],
#  ('2016-03-09', 'IT'): [],
#  ('2016-03-10', 'IT'): [],
#  ('2016-03-11', 'IT'): [],
#  ('2016-03-12', 'IT'): [],
#  ('2016-03-13', 'IT'): [],
#  ('2016-03-14', 'IT'): [],
#  ('2016-03-15', 'IT'): [],
#  ('2016-03-16', 'IT'): [],
#  ('2016-03-17', 'IT'): [],
#  ('2016-03-18', 'IT'): [],
#  ('2016-03-20',
#   'IT'): [{'name': 'March Equinox',
#    'name_local': 'March Equinox',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Seasonal',
#    'date': '03/20/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '20',
#    'week_day': 'Sunday'}],
#  ('2016-03-21', 'IT'): [],
#  ('2016-03-22', 'IT'): [],
#  ('2016-03-23', 'IT'): [],
#  ('2016-03-24', 'IT'): [],
#  ('2016-03-25',
#   'IT'): [{'name': 'Good Friday',
#    'name_local': 'Good Friday',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Observance',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}],
#  ('2016-03-26', 'IT'): [],
#  ('2016-03-27',
#   'IT'): [{'name': 'Easter Sunday',
#    'name_local': 'Easter Sunday',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Observance',
#    'date': '03/27/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '27',
#    'week_day': 'Sunday'}],
#  ('2016-03-28',
#   'IT'): [{'name': 'Easter Monday',
#    'name_local': 'Easter Monday',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '03/28/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '28',
#    'week_day': 'Monday'}],
#  ('2016-03-29', 'IT'): [],
#  ('2016-03-30', 'IT'): [],
#  ('2016-03-31', 'IT'): [],
#  ('2016-04-01', 'IT'): [],
#  ('2016-04-02', 'IT'): [],
#  ('2016-04-03', 'IT'): [],
#  ('2016-04-04', 'IT'): [],
#  ('2016-04-05', 'IT'): [],
#  ('2016-04-06', 'IT'): [],
#  ('2016-04-07', 'IT'): [],
#  ('2016-04-08', 'IT'): [],
#  ('2016-04-09', 'IT'): [],
#  ('2016-04-10', 'IT'): [],
#  ('2016-04-11', 'IT'): [],
#  ('2016-04-12', 'IT'): [],
#  ('2016-04-13', 'IT'): [],
#  ('2016-04-14', 'IT'): [],
#  ('2016-04-15', 'IT'): [],
#  ('2016-04-16', 'IT'): [],
#  ('2016-04-17', 'IT'): [],
#  ('2016-04-18', 'IT'): [],
#  ('2016-04-19', 'IT'): [],
#  ('2016-04-20', 'IT'): [],
#  ('2016-04-21', 'IT'): [],
#  ('2016-04-23', 'IT'): [],
#  ('2016-04-24', 'IT'): [],
#  ('2016-04-25',
#   'IT'): [{'name': 'The Feast of St Mark (Venice)',
#    'name_local': 'The Feast of St Mark (Venice)',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Local holiday',
#    'date': '04/25/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '25',
#    'week_day': 'Monday'}, {'name': 'Liberation Day',
#    'name_local': 'Liberation Day',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '04/25/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '25',
#    'week_day': 'Monday'}],
#  ('2016-04-26', 'IT'): [],
#  ('2016-04-27', 'IT'): [],
#  ('2016-04-28', 'IT'): [],
#  ('2016-04-29', 'IT'): [],
#  ('2016-04-30', 'IT'): [],
#  ('2016-05-01',
#   'IT'): [{'name': 'Labor Day / May Day',
#    'name_local': 'Labor Day / May Day',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '05/01/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '01',
#    'week_day': 'Sunday'}],
#  ('2016-05-02', 'IT'): [],
#  ('2016-05-03', 'IT'): [],
#  ('2016-05-04', 'IT'): [],
#  ('2016-05-05', 'IT'): [],
#  ('2016-05-06', 'IT'): [],
#  ('2016-05-07', 'IT'): [],
#  ('2016-05-08', 'IT'): [],
#  ('2016-05-09', 'IT'): [],
#  ('2016-05-10', 'IT'): [],
#  ('2016-05-11', 'IT'): [],
#  ('2016-05-12', 'IT'): [],
#  ('2016-05-13', 'IT'): [],
#  ('2016-05-14', 'IT'): [],
#  ('2016-05-15', 'IT'): [],
#  ('2016-05-16', 'IT'): [],
#  ('2016-05-17', 'IT'): [],
#  ('2016-05-18', 'IT'): [],
#  ('2016-05-19', 'IT'): [],
#  ('2016-05-20', 'IT'): [],
#  ('2016-05-21', 'IT'): [],
#  ('2016-05-22', 'IT'): [],
#  ('2016-05-23', 'IT'): [],
#  ('2016-05-24', 'IT'): [],
#  ('2016-05-25', 'IT'): [],
#  ('2016-05-26', 'IT'): [],
#  ('2016-05-27', 'IT'): [],
#  ('2016-05-28', 'IT'): [],
#  ('2016-05-29', 'IT'): [],
#  ('2016-05-30', 'IT'): [],
#  ('2016-05-31', 'IT'): [],
#  ('2016-06-01', 'IT'): [],
#  ('2016-01-01',
#   'US'): [{'name': "New Year's Day",
#    'name_local': "New Year's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'National',
#    'date': '01/01/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '01',
#    'week_day': 'Friday'}],
#  ('2016-01-02', 'US'): [],
#  ('2016-01-03', 'US'): [],
#  ('2016-01-04',
#   'US'): [{'name': 'World Braille Day',
#    'name_local': 'World Braille Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '01/04/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '04',
#    'week_day': 'Monday'}],
#  ('2016-01-05', 'US'): [],
#  ('2016-01-06',
#   'US'): [{'name': 'Epiphany',
#    'name_local': 'Epiphany',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '01/06/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '06',
#    'week_day': 'Wednesday'}],
#  ('2016-01-07',
#   'US'): [{'name': 'Orthodox Christmas Day',
#    'name_local': 'Orthodox Christmas Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Orthodox',
#    'date': '01/07/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '07',
#    'week_day': 'Thursday'}, {'name': "International Programmers' Day",
#    'name_local': "International Programmers' Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '01/07/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '07',
#    'week_day': 'Thursday'}],
#  ('2016-01-08', 'US'): [],
#  ('2016-01-09', 'US'): [],
#  ('2016-01-10', 'US'): [],
#  ('2016-01-11', 'US'): [],
#  ('2016-01-12', 'US'): [],
#  ('2016-01-13',
#   'US'): [{'name': 'Stephen Foster Memorial Day',
#    'name_local': 'Stephen Foster Memorial Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '01/13/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '13',
#    'week_day': 'Wednesday'}],
#  ('2016-01-14',
#   'US'): [{'name': 'Orthodox New Year',
#    'name_local': 'Orthodox New Year',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Orthodox',
#    'date': '01/14/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '14',
#    'week_day': 'Thursday'}],
#  ('2016-01-15',
#   'US'): [{'name': 'Lee-Jackson Day',
#    'name_local': 'Lee-Jackson Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Virginia',
#    'type': 'Local holiday',
#    'date': '01/15/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '15',
#    'week_day': 'Friday'}],
#  ('2016-01-16', 'US'): [],
#  ('2016-01-17',
#   'US'): [{'name': 'World Religion Day',
#    'name_local': 'World Religion Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '01/17/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '17',
#    'week_day': 'Sunday'}],
#  ('2016-01-18',
#   'US'): [{'name': "Robert E. Lee's Birthday",
#    'name_local': "Robert E. Lee's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Arkansas',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': "Robert E. Lee's Birthday",
#    'name_local': "Robert E. Lee's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Alabama',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': "Robert E. Lee's Birthday",
#    'name_local': "Robert E. Lee's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': "Robert E. Lee's Birthday",
#    'name_local': "Robert E. Lee's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Mississippi',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': 'Idaho Human Rights Day',
#    'name_local': 'Idaho Human Rights Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Idaho',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': 'Civil Rights Day',
#    'name_local': 'Civil Rights Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - New Hampshire',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': 'Civil Rights Day',
#    'name_local': 'Civil Rights Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Arizona',
#    'type': 'Local holiday',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}, {'name': 'Martin Luther King Jr. Day',
#    'name_local': 'Martin Luther King Jr. Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'National',
#    'date': '01/18/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '18',
#    'week_day': 'Monday'}],
#  ('2016-01-19',
#   'US'): [{'name': "Robert E. Lee's Birthday",
#    'name_local': "Robert E. Lee's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Florida',
#    'type': 'Local holiday',
#    'date': '01/19/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '19',
#    'week_day': 'Tuesday'}, {'name': "Confederate Heroes' Day",
#    'name_local': "Confederate Heroes' Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Texas',
#    'type': 'Local holiday',
#    'date': '01/19/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '19',
#    'week_day': 'Tuesday'}],
#  ('2016-01-20', 'US'): [],
#  ('2016-01-21', 'US'): [],
#  ('2016-01-22', 'US'): [],
#  ('2016-01-23', 'US'): [],
#  ('2016-01-24',
#   'US'): [{'name': 'World Leprosy Day',
#    'name_local': 'World Leprosy Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '01/24/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '24',
#    'week_day': 'Sunday'}],
#  ('2016-01-25',
#   'US'): [{'name': "Tu Bishvat/Tu B'Shevat",
#    'name_local': "Tu Bishvat/Tu B'Shevat",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Hebrew',
#    'date': '01/25/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '25',
#    'week_day': 'Monday'}],
#  ('2016-01-26',
#   'US'): [{'name': 'International Customs Day',
#    'name_local': 'International Customs Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '01/26/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '26',
#    'week_day': 'Tuesday'}],
#  ('2016-01-27',
#   'US'): [{'name': 'International Day of Commemoration in Memory of the Victims of the Holocaust',
#    'name_local': 'International Day of Commemoration in Memory of the Victims of the Holocaust',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '01/27/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '27',
#    'week_day': 'Wednesday'}],
#  ('2016-01-28', 'US'): [],
#  ('2016-01-29',
#   'US'): [{'name': 'Kansas Day',
#    'name_local': 'Kansas Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '01/29/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '29',
#    'week_day': 'Friday'}],
#  ('2016-01-30', 'US'): [],
#  ('2016-01-31', 'US'): [],
#  ('2016-02-01',
#   'US'): [{'name': 'National Freedom Day',
#    'name_local': 'National Freedom Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '02/01/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '01',
#    'week_day': 'Monday'}],
#  ('2016-02-02',
#   'US'): [{'name': 'World Wetlands Day',
#    'name_local': 'World Wetlands Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '02/02/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '02',
#    'week_day': 'Tuesday'}, {'name': 'Groundhog Day',
#    'name_local': 'Groundhog Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '02/02/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '02',
#    'week_day': 'Tuesday'}],
#  ('2016-02-03', 'US'): [],
#  ('2016-02-04',
#   'US'): [{'name': 'Rosa Parks Day',
#    'name_local': 'Rosa Parks Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Missouri',
#    'type': 'Local observance',
#    'date': '02/04/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '04',
#    'week_day': 'Thursday'}, {'name': 'Rosa Parks Day',
#    'name_local': 'Rosa Parks Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - California',
#    'type': 'Local observance',
#    'date': '02/04/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '04',
#    'week_day': 'Thursday'}, {'name': 'World Cancer Day',
#    'name_local': 'World Cancer Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '02/04/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '04',
#    'week_day': 'Thursday'}],
#  ('2016-02-05',
#   'US'): [{'name': 'National Wear Red Day',
#    'name_local': 'National Wear Red Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '02/05/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '05',
#    'week_day': 'Friday'}],
#  ('2016-02-06',
#   'US'): [{'name': 'International Day of Zero Tolerance for Female Genital Mutilation',
#    'name_local': 'International Day of Zero Tolerance for Female Genital Mutilation',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '02/06/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '06',
#    'week_day': 'Saturday'}],
#  ('2016-02-07',
#   'US'): [{'name': 'Super Bowl',
#    'name_local': 'Super Bowl',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Sporting',
#    'date': '02/07/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '07',
#    'week_day': 'Sunday'}],
#  ('2016-02-08',
#   'US'): [{'name': 'Chinese New Year',
#    'name_local': 'Chinese New Year',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '02/08/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '08',
#    'week_day': 'Monday'}],
#  ('2016-02-09',
#   'US'): [{'name': 'Shrove Tuesday/Mardi Gras',
#    'name_local': 'Shrove Tuesday/Mardi Gras',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Louisiana',
#    'type': 'Local holiday',
#    'date': '02/09/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '09',
#    'week_day': 'Tuesday'}, {'name': 'Shrove Tuesday/Mardi Gras',
#    'name_local': 'Shrove Tuesday/Mardi Gras',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Alabama',
#    'type': 'Local holiday',
#    'date': '02/09/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '09',
#    'week_day': 'Tuesday'}, {'name': 'Shrove Tuesday/Mardi Gras',
#    'name_local': 'Shrove Tuesday/Mardi Gras',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Florida',
#    'type': 'Local observance',
#    'date': '02/09/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '09',
#    'week_day': 'Tuesday'}, {'name': 'Shrove Tuesday/Mardi Gras',
#    'name_local': 'Shrove Tuesday/Mardi Gras',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '02/09/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '09',
#    'week_day': 'Tuesday'}],
#  ('2016-02-10',
#   'US'): [{'name': 'Ash Wednesday',
#    'name_local': 'Ash Wednesday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '02/10/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '10',
#    'week_day': 'Wednesday'}],
#  ('2016-02-11',
#   'US'): [{'name': 'World Day of the Sick',
#    'name_local': 'World Day of the Sick',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '02/11/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '11',
#    'week_day': 'Thursday'}, {'name': 'International Day of Women and Girls in Science',
#    'name_local': 'International Day of Women and Girls in Science',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '02/11/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '11',
#    'week_day': 'Thursday'}],
#  ('2016-02-12',
#   'US'): [{'name': "Lincoln's Birthday",
#    'name_local': "Lincoln's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Connecticut, Illinois, New York, Missouri',
#    'type': 'Local holiday',
#    'date': '02/12/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '12',
#    'week_day': 'Friday'}, {'name': "Lincoln's Birthday",
#    'name_local': "Lincoln's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Florida',
#    'type': 'Local observance',
#    'date': '02/12/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '12',
#    'week_day': 'Friday'}],
#  ('2016-02-13',
#   'US'): [{'name': 'World Radio Day',
#    'name_local': 'World Radio Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '02/13/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '13',
#    'week_day': 'Saturday'}],
#  ('2016-02-14',
#   'US'): [{'name': 'Statehood Day',
#    'name_local': 'Statehood Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Arizona',
#    'type': 'Local observance',
#    'date': '02/14/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '14',
#    'week_day': 'Sunday'}, {'name': "Valentine's Day",
#    'name_local': "Valentine's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '02/14/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '14',
#    'week_day': 'Sunday'}],
#  ('2016-02-15',
#   'US'): [{'name': 'Daisy Gatson Bates Day',
#    'name_local': 'Daisy Gatson Bates Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Arkansas',
#    'type': 'Local holiday',
#    'date': '02/15/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '15',
#    'week_day': 'Monday'}, {'name': "Susan B. Anthony's Birthday",
#    'name_local': "Susan B. Anthony's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Florida',
#    'type': 'Local observance',
#    'date': '02/15/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '15',
#    'week_day': 'Monday'}, {'name': "Susan B. Anthony's Birthday",
#    'name_local': "Susan B. Anthony's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - New York',
#    'type': 'Local observance',
#    'date': '02/15/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '15',
#    'week_day': 'Monday'}, {'name': "Susan B. Anthony's Birthday",
#    'name_local': "Susan B. Anthony's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Wisconsin',
#    'type': 'Local observance',
#    'date': '02/15/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '15',
#    'week_day': 'Monday'}, {'name': "Susan B. Anthony's Birthday",
#    'name_local': "Susan B. Anthony's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - California',
#    'type': 'Local observance',
#    'date': '02/15/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '15',
#    'week_day': 'Monday'}, {'name': "Presidents' Day",
#    'name_local': "Presidents' Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Alabama, Alaska, Arizona, Arkansas, California, Colorado, Connecticut, District of Columbia, Florida, Hawaii, Idaho, Illinois, Maine, Maryland, Massachusetts, Michigan, Minnesota, Mississippi, Missouri, Montana, Nebraska, Nevada, New Hampshire, New Jersey, New York, North Dakota, Ohio, Oklahoma, Oregon, Pennsylvania, South Carolina, South Dakota, Tennessee, Texas, Utah, Vermont, Virginia, Washington, West Virginia, Wyoming',
#    'type': 'National',
#    'date': '02/15/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '15',
#    'week_day': 'Monday'}],
#  ('2016-02-16',
#   'US'): [{'name': 'Elizabeth Peratrovich Day',
#    'name_local': 'Elizabeth Peratrovich Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Alaska',
#    'type': 'Local observance',
#    'date': '02/16/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '16',
#    'week_day': 'Tuesday'}],
#  ('2016-02-17', 'US'): [],
#  ('2016-02-18', 'US'): [],
#  ('2016-02-19', 'US'): [],
#  ('2016-02-20',
#   'US'): [{'name': 'World Day of Social Justice',
#    'name_local': 'World Day of Social Justice',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '02/20/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '20',
#    'week_day': 'Saturday'}],
#  ('2016-02-21',
#   'US'): [{'name': 'International Mother Language Day',
#    'name_local': 'International Mother Language Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '02/21/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '21',
#    'week_day': 'Sunday'}],
#  ('2016-02-22', 'US'): [],
#  ('2016-02-23', 'US'): [],
#  ('2016-02-24', 'US'): [],
#  ('2016-02-25', 'US'): [],
#  ('2016-02-26', 'US'): [],
#  ('2016-02-27', 'US'): [],
#  ('2016-02-28',
#   'US'): [{'name': 'Linus Pauling Day',
#    'name_local': 'Linus Pauling Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Oregon',
#    'type': 'Local observance',
#    'date': '02/28/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '28',
#    'week_day': 'Sunday'}],
#  ('2016-02-29',
#   'US'): [{'name': 'Leap Day',
#    'name_local': 'Leap Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '02/29/2016',
#    'date_year': '2016',
#    'date_month': '02',
#    'date_day': '29',
#    'week_day': 'Monday'}],
#  ('2016-03-01',
#   'US'): [{'name': 'Town Meeting Day',
#    'name_local': 'Town Meeting Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Vermont',
#    'type': 'Local holiday',
#    'date': '03/01/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '01',
#    'week_day': 'Tuesday'}, {'name': 'Self-Injury Awareness Day',
#    'name_local': 'Self-Injury Awareness Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '03/01/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '01',
#    'week_day': 'Tuesday'}, {'name': "St. David's Day",
#    'name_local': "St. David's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '03/01/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '01',
#    'week_day': 'Tuesday'}, {'name': 'Zero Discrimination Day',
#    'name_local': 'Zero Discrimination Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/01/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '01',
#    'week_day': 'Tuesday'}],
#  ('2016-03-02',
#   'US'): [{'name': 'Texas Independence Day',
#    'name_local': 'Texas Independence Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Texas',
#    'type': 'Local holiday',
#    'date': '03/02/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '02',
#    'week_day': 'Wednesday'}, {'name': 'Read Across America Day',
#    'name_local': 'Read Across America Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '03/02/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '02',
#    'week_day': 'Wednesday'}],
#  ('2016-03-03',
#   'US'): [{'name': 'World Wildlife Day',
#    'name_local': 'World Wildlife Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/03/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '03',
#    'week_day': 'Thursday'}],
#  ('2016-03-04',
#   'US'): [{'name': 'Employee Appreciation Day',
#    'name_local': 'Employee Appreciation Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '03/04/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '04',
#    'week_day': 'Friday'}],
#  ('2016-03-05', 'US'): [],
#  ('2016-03-06', 'US'): [],
#  ('2016-03-07',
#   'US'): [{'name': 'Maha Shivaratri',
#    'name_local': 'Maha Shivaratri',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Hindu',
#    'date': '03/07/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '07',
#    'week_day': 'Monday'}, {'name': 'Casimir Pulaski Day',
#    'name_local': 'Casimir Pulaski Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Illinois',
#    'type': 'Local observance',
#    'date': '03/07/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '07',
#    'week_day': 'Monday'}],
#  ('2016-03-08',
#   'US'): [{'name': "International Women's Day",
#    'name_local': "International Women's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/08/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '08',
#    'week_day': 'Tuesday'}],
#  ('2016-03-09', 'US'): [],
#  ('2016-03-10',
#   'US'): [{'name': 'World Kidney Day',
#    'name_local': 'World Kidney Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '03/10/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '10',
#    'week_day': 'Thursday'}],
#  ('2016-03-11', 'US'): [],
#  ('2016-03-12', 'US'): [],
#  ('2016-03-13',
#   'US'): [{'name': 'Daylight Saving Time starts',
#    'name_local': 'Daylight Saving Time starts',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Clock change',
#    'date': '03/13/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '13',
#    'week_day': 'Sunday'}],
#  ('2016-03-14', 'US'): [],
#  ('2016-03-15', 'US'): [],
#  ('2016-03-16', 'US'): [],
#  ('2016-03-17',
#   'US'): [{'name': 'Evacuation Day',
#    'name_local': 'Evacuation Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Massachusetts',
#    'type': 'Local holiday',
#    'date': '03/17/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '17',
#    'week_day': 'Thursday'}, {'name': "St. Patrick's Day",
#    'name_local': "St. Patrick's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '03/17/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '17',
#    'week_day': 'Thursday'}],
#  ('2016-03-18', 'US'): [],
#  ('2016-03-20',
#   'US'): [{'name': 'Palm Sunday',
#    'name_local': 'Palm Sunday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '03/20/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '20',
#    'week_day': 'Sunday'}, {'name': 'March Equinox',
#    'name_local': 'March Equinox',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Seasonal',
#    'date': '03/20/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '20',
#    'week_day': 'Sunday'}, {'name': 'International Day of Happiness',
#    'name_local': 'International Day of Happiness',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/20/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '20',
#    'week_day': 'Sunday'}],
#  ('2016-03-21',
#   'US'): [{'name': 'International Day for the Elimination of Racial Discrimination',
#    'name_local': 'International Day for the Elimination of Racial Discrimination',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/21/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '21',
#    'week_day': 'Monday'}, {'name': 'World Poetry Day',
#    'name_local': 'World Poetry Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/21/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '21',
#    'week_day': 'Monday'}, {'name': 'International Day of Nowruz',
#    'name_local': 'International Day of Nowruz',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/21/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '21',
#    'week_day': 'Monday'}, {'name': 'World Down Syndrome Day',
#    'name_local': 'World Down Syndrome Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/21/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '21',
#    'week_day': 'Monday'}, {'name': 'International Day of Forests',
#    'name_local': 'International Day of Forests',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/21/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '21',
#    'week_day': 'Monday'}],
#  ('2016-03-22',
#   'US'): [{'name': 'World Water Day',
#    'name_local': 'World Water Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/22/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '22',
#    'week_day': 'Tuesday'}],
#  ('2016-03-23',
#   'US'): [{'name': 'Holi',
#    'name_local': 'Holi',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Hindu',
#    'date': '03/23/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '23',
#    'week_day': 'Wednesday'}, {'name': 'World Meteorological Day',
#    'name_local': 'World Meteorological Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/23/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '23',
#    'week_day': 'Wednesday'}],
#  ('2016-03-24',
#   'US'): [{'name': 'Maundy Thursday',
#    'name_local': 'Maundy Thursday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '03/24/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '24',
#    'week_day': 'Thursday'}, {'name': 'Purim',
#    'name_local': 'Purim',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Hebrew',
#    'date': '03/24/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '24',
#    'week_day': 'Thursday'}, {'name': 'World Tuberculosis Day',
#    'name_local': 'World Tuberculosis Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/24/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '24',
#    'week_day': 'Thursday'}, {'name': 'International Day for the Right to the Truth concerning Gross Human Rights Violations and for the Dignity of Victims',
#    'name_local': 'International Day for the Right to the Truth concerning Gross Human Rights Violations and for the Dignity of Victims',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/24/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '24',
#    'week_day': 'Thursday'}],
#  ('2016-03-25',
#   'US'): [{'name': 'Prince Jonah Kuhio Kalanianaole Day',
#    'name_local': 'Prince Jonah Kuhio Kalanianaole Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Hawaii',
#    'type': 'Local holiday',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}, {'name': 'Good Friday',
#    'name_local': 'Good Friday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Connecticut, Hawaii, Delaware, Indiana, Kentucky, Louisiana, New Jersey, North Carolina, North Dakota, Tennessee, Texas',
#    'type': 'Local holiday, Christian',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}, {'name': 'Maryland Day',
#    'name_local': 'Maryland Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Maryland',
#    'type': 'Local observance',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}, {'name': 'International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade',
#    'name_local': 'International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}, {'name': 'International Day of Solidarity with Detained and Missing Staff Members',
#    'name_local': 'International Day of Solidarity with Detained and Missing Staff Members',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}],
#  ('2016-03-26',
#   'US'): [{'name': 'Holy Saturday',
#    'name_local': 'Holy Saturday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '03/26/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '26',
#    'week_day': 'Saturday'}, {'name': 'Prince Jonah Kuhio Kalanianaole Day',
#    'name_local': 'Prince Jonah Kuhio Kalanianaole Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Hawaii',
#    'type': 'Local holiday',
#    'date': '03/26/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '26',
#    'week_day': 'Saturday'}],
#  ('2016-03-27',
#   'US'): [{'name': 'Easter Sunday',
#    'name_local': 'Easter Sunday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '03/27/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '27',
#    'week_day': 'Sunday'}],
#  ('2016-03-28',
#   'US'): [{'name': "Seward's Day",
#    'name_local': "Seward's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Alaska',
#    'type': 'Local holiday',
#    'date': '03/28/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '28',
#    'week_day': 'Monday'}, {'name': 'Easter Monday',
#    'name_local': 'Easter Monday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '03/28/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '28',
#    'week_day': 'Monday'}],
#  ('2016-03-29', 'US'): [],
#  ('2016-03-30', 'US'): [],
#  ('2016-03-31',
#   'US'): [{'name': 'César Chávez Day',
#    'name_local': 'César Chávez Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Texas',
#    'type': 'Local holiday',
#    'date': '03/31/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '31',
#    'week_day': 'Thursday'}, {'name': 'César Chávez Day',
#    'name_local': 'César Chávez Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Arizona, Michigan, Nevada, New Mexico, Utah, Wisconsin, Washington',
#    'type': 'Local holiday',
#    'date': '03/31/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '31',
#    'week_day': 'Thursday'}, {'name': 'César Chávez Day',
#    'name_local': 'César Chávez Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Colorado',
#    'type': 'Local holiday',
#    'date': '03/31/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '31',
#    'week_day': 'Thursday'}, {'name': 'César Chávez Day',
#    'name_local': 'César Chávez Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - California',
#    'type': 'Local holiday',
#    'date': '03/31/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '31',
#    'week_day': 'Thursday'}],
#  ('2016-04-01',
#   'US'): [{'name': 'Pascua Florida Day',
#    'name_local': 'Pascua Florida Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Florida',
#    'type': 'Local observance',
#    'date': '04/01/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '01',
#    'week_day': 'Friday'}, {'name': "April Fool's Day",
#    'name_local': "April Fool's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '04/01/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '01',
#    'week_day': 'Friday'}],
#  ('2016-04-02',
#   'US'): [{'name': 'Pascua Florida Day',
#    'name_local': 'Pascua Florida Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Florida',
#    'type': 'Local observance',
#    'date': '04/02/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '02',
#    'week_day': 'Saturday'}, {'name': 'World Autism Awareness Day',
#    'name_local': 'World Autism Awareness Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '04/02/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '02',
#    'week_day': 'Saturday'}],
#  ('2016-04-03', 'US'): [],
#  ('2016-04-04',
#   'US'): [{'name': "United Nations' Mine Awareness Day",
#    'name_local': "United Nations' Mine Awareness Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '04/04/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '04',
#    'week_day': 'Monday'}],
#  ('2016-04-05', 'US'): [],
#  ('2016-04-06',
#   'US'): [{'name': 'National Tartan Day',
#    'name_local': 'National Tartan Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '04/06/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '06',
#    'week_day': 'Wednesday'}, {'name': 'International Day of Sport for Development and Peace',
#    'name_local': 'International Day of Sport for Development and Peace',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '04/06/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '06',
#    'week_day': 'Wednesday'}],
#  ('2016-04-07',
#   'US'): [{'name': "United Nations' World Health Day",
#    'name_local': "United Nations' World Health Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '04/07/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '07',
#    'week_day': 'Thursday'}, {'name': 'Day of Remembrance of the Victims of the Rwanda Genocide',
#    'name_local': 'Day of Remembrance of the Victims of the Rwanda Genocide',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '04/07/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '07',
#    'week_day': 'Thursday'}],
#  ('2016-04-08', 'US'): [],
#  ('2016-04-09', 'US'): [],
#  ('2016-04-10', 'US'): [],
#  ('2016-04-11', 'US'): [],
#  ('2016-04-12',
#   'US'): [{'name': "National Library Workers' Day",
#    'name_local': "National Library Workers' Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '04/12/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '12',
#    'week_day': 'Tuesday'}, {'name': 'International Day of Human Space Flight',
#    'name_local': 'International Day of Human Space Flight',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '04/12/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '12',
#    'week_day': 'Tuesday'}],
#  ('2016-04-13',
#   'US'): [{'name': "Thomas Jefferson's Birthday",
#    'name_local': "Thomas Jefferson's Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '04/13/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '13',
#    'week_day': 'Wednesday'}],
#  ('2016-04-14', 'US'): [],
#  ('2016-04-15',
#   'US'): [{'name': 'Emancipation Day',
#    'name_local': 'Emancipation Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - District of Columbia',
#    'type': 'Local holiday',
#    'date': '04/15/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '15',
#    'week_day': 'Friday'}, {'name': 'Father Damien Day',
#    'name_local': 'Father Damien Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Hawaii',
#    'type': 'Local observance',
#    'date': '04/15/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '15',
#    'week_day': 'Friday'}, {'name': 'Global Youth Service Day',
#    'name_local': 'Global Youth Service Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
# ...
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/05/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '05',
#    'week_day': 'Thursday'}, {'name': 'National Day of Prayer',
#    'name_local': 'National Day of Prayer',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/05/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '05',
#    'week_day': 'Thursday'}],
#  ('2016-05-06',
#   'US'): [{'name': 'National Nurses Day',
#    'name_local': 'National Nurses Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/06/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '06',
#    'week_day': 'Friday'}, {'name': 'Military Spouse Appreciation Day',
#    'name_local': 'Military Spouse Appreciation Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/06/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '06',
#    'week_day': 'Friday'}, {'name': 'Kentucky Oaks',
#    'name_local': 'Kentucky Oaks',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Sporting',
#    'date': '05/06/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '06',
#    'week_day': 'Friday'}],
#  ('2016-05-07',
#   'US'): [{'name': 'National Explosive Ordnance Disposal (EOD) Day',
#    'name_local': 'National Explosive Ordnance Disposal (EOD) Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/07/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '07',
#    'week_day': 'Saturday'}, {'name': 'Kentucky Derby',
#    'name_local': 'Kentucky Derby',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Sporting',
#    'date': '05/07/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '07',
#    'week_day': 'Saturday'}],
#  ('2016-05-08',
#   'US'): [{'name': 'Truman Day',
#    'name_local': 'Truman Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Missouri',
#    'type': 'Local holiday',
#    'date': '05/08/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '08',
#    'week_day': 'Sunday'}, {'name': 'World Ovarian Cancer Day',
#    'name_local': 'World Ovarian Cancer Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '05/08/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '08',
#    'week_day': 'Sunday'}, {'name': "Mother's Day",
#    'name_local': "Mother's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/08/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '08',
#    'week_day': 'Sunday'}, {'name': 'Victory in Europe Day',
#    'name_local': 'Victory in Europe Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/08/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '08',
#    'week_day': 'Sunday'}, {'name': 'Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War',
#    'name_local': 'Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/08/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '08',
#    'week_day': 'Sunday'}],
#  ('2016-05-09',
#   'US'): [{'name': 'Truman Day',
#    'name_local': 'Truman Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Missouri',
#    'type': 'Local holiday',
#    'date': '05/09/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '09',
#    'week_day': 'Monday'}],
#  ('2016-05-10',
#   'US'): [{'name': 'Confederate Memorial Day',
#    'name_local': 'Confederate Memorial Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - South Carolina',
#    'type': 'Local holiday',
#    'date': '05/10/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '10',
#    'week_day': 'Tuesday'}, {'name': 'Primary Election Day',
#    'name_local': 'Primary Election Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - West Virginia',
#    'type': 'Local holiday',
#    'date': '05/10/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '10',
#    'week_day': 'Tuesday'}, {'name': 'Confederate Memorial Day',
#    'name_local': 'Confederate Memorial Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - North Carolina',
#    'type': 'Local observance',
#    'date': '05/10/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '10',
#    'week_day': 'Tuesday'}],
#  ('2016-05-11', 'US'): [],
#  ('2016-05-12',
#   'US'): [{'name': "Yom Ha'atzmaut",
#    'name_local': "Yom Ha'atzmaut",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Hebrew',
#    'date': '05/12/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '12',
#    'week_day': 'Thursday'}, {'name': 'International Nurses Day',
#    'name_local': 'International Nurses Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '05/12/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '12',
#    'week_day': 'Thursday'}],
#  ('2016-05-13',
#   'US'): [{'name': 'Friday the 13th',
#    'name_local': 'Friday the 13th',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '05/13/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '13',
#    'week_day': 'Friday'}],
#  ('2016-05-14',
#   'US'): [{'name': 'World Migratory Bird Day',
#    'name_local': 'World Migratory Bird Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/14/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '14',
#    'week_day': 'Saturday'}],
#  ('2016-05-15',
#   'US'): [{'name': 'Pentecost',
#    'name_local': 'Pentecost',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '05/15/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '15',
#    'week_day': 'Sunday'}, {'name': 'Peace Officers Memorial Day',
#    'name_local': 'Peace Officers Memorial Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/15/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '15',
#    'week_day': 'Sunday'}, {'name': 'International Day of Families',
#    'name_local': 'International Day of Families',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/15/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '15',
#    'week_day': 'Sunday'}],
#  ('2016-05-16',
#   'US'): [{'name': 'Whit Monday',
#    'name_local': 'Whit Monday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '05/16/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '16',
#    'week_day': 'Monday'}],
#  ('2016-05-17',
#   'US'): [{'name': 'World Information Society Day',
#    'name_local': 'World Information Society Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/17/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '17',
#    'week_day': 'Tuesday'}],
#  ('2016-05-18', 'US'): [],
#  ('2016-05-19', 'US'): [],
#  ('2016-05-20',
#   'US'): [{'name': 'World Autoimmune Arthritis Day',
#    'name_local': 'World Autoimmune Arthritis Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '05/20/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '20',
#    'week_day': 'Friday'}, {'name': 'National Defense Transportation Day',
#    'name_local': 'National Defense Transportation Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/20/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '20',
#    'week_day': 'Friday'}, {'name': 'Day of Vesak',
#    'name_local': 'Day of Vesak',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/20/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '20',
#    'week_day': 'Friday'}],
#  ('2016-05-21',
#   'US'): [{'name': 'Armed Forces Day',
#    'name_local': 'Armed Forces Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/21/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '21',
#    'week_day': 'Saturday'}, {'name': 'Preakness Stakes',
#    'name_local': 'Preakness Stakes',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Sporting',
#    'date': '05/21/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '21',
#    'week_day': 'Saturday'}, {'name': 'World Day for Cultural Diversity for Dialogue and Development',
#    'name_local': 'World Day for Cultural Diversity for Dialogue and Development',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/21/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '21',
#    'week_day': 'Saturday'}],
#  ('2016-05-22',
#   'US'): [{'name': 'Trinity Sunday',
#    'name_local': 'Trinity Sunday',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '05/22/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '22',
#    'week_day': 'Sunday'}, {'name': 'Harvey Milk Day',
#    'name_local': 'Harvey Milk Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - California',
#    'type': 'Local observance',
#    'date': '05/22/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '22',
#    'week_day': 'Sunday'}, {'name': 'National Maritime Day',
#    'name_local': 'National Maritime Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/22/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '22',
#    'week_day': 'Sunday'}, {'name': 'International Day for Biological Diversity',
#    'name_local': 'International Day for Biological Diversity',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/22/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '22',
#    'week_day': 'Sunday'}],
#  ('2016-05-23',
#   'US'): [{'name': 'International Day to End Obstetric Fistula',
#    'name_local': 'International Day to End Obstetric Fistula',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/23/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '23',
#    'week_day': 'Monday'}],
#  ('2016-05-24', 'US'): [],
#  ('2016-05-25',
#   'US'): [{'name': 'African Liberation Day',
#    'name_local': 'African Liberation Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Worldwide',
#    'date': '05/25/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '25',
#    'week_day': 'Wednesday'}, {'name': 'Emergency Medical Services for Children Day',
#    'name_local': 'Emergency Medical Services for Children Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/25/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '25',
#    'week_day': 'Wednesday'}, {'name': "National Missing Children's Day",
#    'name_local': "National Missing Children's Day",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Observance',
#    'date': '05/25/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '25',
#    'week_day': 'Wednesday'}],
#  ('2016-05-26',
#   'US'): [{'name': 'Corpus Christi',
#    'name_local': 'Corpus Christi',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Christian',
#    'date': '05/26/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '26',
#    'week_day': 'Thursday'}, {'name': 'Lag BaOmer',
#    'name_local': 'Lag BaOmer',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'Hebrew',
#    'date': '05/26/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '26',
#    'week_day': 'Thursday'}],
#  ('2016-05-27', 'US'): [],
#  ('2016-05-28', 'US'): [],
#  ('2016-05-29',
#   'US'): [{'name': 'International Day of United Nations Peacekeepers',
#    'name_local': 'International Day of United Nations Peacekeepers',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/29/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '29',
#    'week_day': 'Sunday'}],
#  ('2016-05-30',
#   'US'): [{'name': "Jefferson Davis' Birthday",
#    'name_local': "Jefferson Davis' Birthday",
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Mississippi',
#    'type': 'Local observance',
#    'date': '05/30/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '30',
#    'week_day': 'Monday'}, {'name': 'Memorial Day',
#    'name_local': 'Memorial Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'National',
#    'date': '05/30/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '30',
#    'week_day': 'Monday'}],
#  ('2016-05-31',
#   'US'): [{'name': 'World No Tobacco Day',
#    'name_local': 'World No Tobacco Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '05/31/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '31',
#    'week_day': 'Tuesday'}],
#  ('2016-06-01',
#   'US'): [{'name': 'Statehood Day',
#    'name_local': 'Statehood Day',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States - Kentucky, Tennessee',
#    'type': 'Local observance',
#    'date': '06/01/2016',
#    'date_year': '2016',
#    'date_month': '06',
#    'date_day': '01',
#    'week_day': 'Wednesday'}, {'name': 'Global Day of Parents',
#    'name_local': 'Global Day of Parents',
#    'language': 'en',
#    'description': '',
#    'country': 'US',
#    'location': 'United States',
#    'type': 'UN observance',
#    'date': '06/01/2016',
#    'date_year': '2016',
#    'date_month': '06',
#    'date_day': '01',
#    'week_day': 'Wednesday'}]}

# %%
all_dates_country_cleaned = {k: v for k, v in all_dates_country.items() if len(v) > 0}

# %%
all_dates_country_cleaned
# Out:
# {('2016-01-01',
#   'IT'): [{'name': "New Year's Day",
#    'name_local': "New Year's Day",
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '01/01/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '01',
#    'week_day': 'Friday'}],
#  ('2016-01-06',
#   'IT'): [{'name': 'Epiphany',
#    'name_local': 'Epiphany',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '01/06/2016',
#    'date_year': '2016',
#    'date_month': '01',
#    'date_day': '06',
#    'week_day': 'Wednesday'}],
#  ('2016-03-20',
#   'IT'): [{'name': 'March Equinox',
#    'name_local': 'March Equinox',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Seasonal',
#    'date': '03/20/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '20',
#    'week_day': 'Sunday'}],
#  ('2016-03-25',
#   'IT'): [{'name': 'Good Friday',
#    'name_local': 'Good Friday',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Observance',
#    'date': '03/25/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '25',
#    'week_day': 'Friday'}],
#  ('2016-03-27',
#   'IT'): [{'name': 'Easter Sunday',
#    'name_local': 'Easter Sunday',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Observance',
#    'date': '03/27/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '27',
#    'week_day': 'Sunday'}],
#  ('2016-03-28',
#   'IT'): [{'name': 'Easter Monday',
#    'name_local': 'Easter Monday',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '03/28/2016',
#    'date_year': '2016',
#    'date_month': '03',
#    'date_day': '28',
#    'week_day': 'Monday'}],
#  ('2016-04-25',
#   'IT'): [{'name': 'The Feast of St Mark (Venice)',
#    'name_local': 'The Feast of St Mark (Venice)',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'Local holiday',
#    'date': '04/25/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '25',
#    'week_day': 'Monday'}, {'name': 'Liberation Day',
#    'name_local': 'Liberation Day',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '04/25/2016',
#    'date_year': '2016',
#    'date_month': '04',
#    'date_day': '25',
#    'week_day': 'Monday'}],
#  ('2016-05-01',
#   'IT'): [{'name': 'Labor Day / May Day',
#    'name_local': 'Labor Day / May Day',
#    'language': 'it',
#    'description': '',
#    'country': 'IT',
#    'location': 'Italy',
#    'type': 'National',
#    'date': '05/01/2016',
#    'date_year': '2016',
#    'date_month': '05',
#    'date_day': '01',
#    'week_day': 'Sunday'}]}
