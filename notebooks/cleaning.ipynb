# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/youtube/dataset.csv")
# Out:
# C:\Users\ASM EL Masrya\AppData\Local\Temp\ipykernel_7548\3902940432.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/youtube/dataset.csv")

# %% [markdown]
# # Uniqueness

# %%
no_dup = df.drop_duplicates()

# %%
unique_videos = no_dup.drop_duplicates(subset=["video_id"])

# %%
# no_dup.sort_values(by="is_trending", ascending=False).drop_duplicates(subset=["video_id"], keep="first")

# %% [markdown]
# # Info

# %%
unique_videos.head()
# Out:
#       video_id                                              title  \
# 0  G4M_621v1As       college farewell video#trending #viralshorts
# 1  z2voqo_Jhx4  Busking in Manchester 🇬🇧 #blindfaith #guitar #...
# 2  jHIt9oHFLsw  This is what happens when you play Star Wars i...
# 3  gwRqLbWqKlM  LISA - FUTW (YouTube Music Nights Special Stag...
# 4  prpRoyrutcE        Uljhi hai yeh kis jaal me tu…. Bengaluru ❤️
#
#             publishedAt                 channelId      channelTitle  \
# 0  2025-04-12T02:06:42Z  UC7k_7IF3s3TY-cowwxs_yWw       Vk_07_rider
# 1  2025-04-06T11:35:53Z  UCM_9JHB3xXPSzJfTkD86AtA  Leonardo Patrick
# 2  2025-04-06T10:07:12Z  UC4YyKY5o60Kckk-GXOnhT2g     Violin Phonix
# 3  2025-03-19T03:29:33Z  UC6-BgjsBa5R3PZQ_kZ8hKPg    LLOUD Official
# 4  2025-04-14T10:17:58Z  UCiFXnvi8ESDukE25ol2foWQ         Mr.KiranJ
#
#    categoryId trending_date  \
# 0        22.0    2025-11-08
# 1        10.0    2025-11-08
# 2        22.0    2025-11-08
# 3        10.0    2025-11-08
# 4        10.0    2025-11-08
#
#                                                 tags   view_count      likes  \
# 0  college farewell video, DDU farewell video, fa...  125784084.0  1557178.0
# 1                                                NaN   94744011.0   925529.0
# 2                                                NaN   61945818.0  1067412.0
# 3  Blackpink, Lisa, Music, Fashion, K-Pop, kpop, ...   14555963.0   455816.0
# 4                                                NaN   26204942.0   336267.0
#
#    ...  chapter_count chapters playability_status  supports_miniplayer  \
# 0  ...            0.0       []                 OK                 True
# 1  ...            0.0       []                 OK                 True
# 2  ...            0.0       []                 OK                 True
# 3  ...            0.0       []                 OK                 True
# 4  ...            0.0       []                 OK                 True
#
#   card_count                                              cards is_verified  \
# 0        1.0  [{'teaser_text': 'الاطّلاع على التصحيحَين', 's...       False
# 1        1.0  [{'teaser_text': 'الاطّلاع على التصحيحَين', 's...       False
# 2        1.0  [{'teaser_text': 'الاطّلاع على التصحيحَين', 's...        True
# 3        1.0  [{'teaser_text': 'الاطّلاع على التصحيحَين', 's...        True
# 4        1.0  [{'teaser_text': 'الاطّلاع على التصحيحَين', 's...        True
#
#                badge_labels has_paid_promotion comments_disabled
# 0                        []              False             False
# 1                        []              False             False
# 2  ['قناة الفنّان الرسمية']              False             False
# 3  ['قناة الفنّان الرسمية']              False             False
# 4      ['تم إثبات الملكية']              False             False
#
# [5 rows x 37 columns]

# %%
unique_videos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190915 entries, 0 to 391090
# Data columns (total 37 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   video_id                                  190915 non-null  object
#  1   title                                     190915 non-null  object
#  2   publishedAt                               190915 non-null  object
#  3   channelId                                 190915 non-null  object
#  4   channelTitle                              190915 non-null  object
#  5   categoryId                                190915 non-null  float64
#  6   trending_date                             35796 non-null   object
#  7   tags                                      119066 non-null  object
#  8   view_count                                190892 non-null  float64
#  9   likes                                     190770 non-null  float64
#  10  comment_count                             190867 non-null  float64
#  11  thumbnail_link                            190915 non-null  object
#  12  description                               148771 non-null  object
#  13  is_trending                               190915 non-null  int64
#  14  defaultLanguage                           183454 non-null  object
#  15  duration                                  183450 non-null  object
#  16  dimension                                 183454 non-null  object
#  17  definition                                183454 non-null  object
#  18  caption                                   183454 non-null  object
#  19  licensedContent                           183454 non-null  object
#  20  projection                                183454 non-null  object
#  21  embeddable                                183454 non-null  object
#  22  madeForKids                               183454 non-null  object
#  23  favoriteCount                             183454 non-null  float64
#  24  contentDetails.regionRestriction.blocked  9367 non-null    object
#  25  contentDetails.regionRestriction.allowed  3610 non-null    object
#  26  contentDetails.contentRating.ytRating     254 non-null     object
#  27  chapter_count                             186148 non-null  float64
#  28  chapters                                  186148 non-null  object
#  29  playability_status                        186148 non-null  object
#  30  supports_miniplayer                       186148 non-null  object
#  31  card_count                                186148 non-null  float64
#  32  cards                                     186148 non-null  object
#  33  is_verified                               186148 non-null  object
#  34  badge_labels                              186148 non-null  object
#  35  has_paid_promotion                        186148 non-null  object
#  36  comments_disabled                         190881 non-null  object
# dtypes: float64(7), int64(1), object(29)
# memory usage: 55.3+ MB

# %%
unique_videos.describe()
# Out:
#           categoryId    view_count         likes  comment_count  \
# count  190915.000000  1.908920e+05  1.907700e+05   1.908670e+05
# mean       21.236996  8.343575e+06  1.581203e+05   2.129324e+03
# std         6.264864  5.632930e+07  7.151850e+05   3.037718e+04
# min         1.000000  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        20.000000  1.393095e+05  1.934000e+03   3.300000e+01
# 50%        22.000000  5.565105e+05  1.457650e+04   3.060000e+02
# 75%        24.000000  2.681506e+06  6.727875e+04   1.344000e+03
# max        30.000000  4.168919e+09  4.337832e+07   1.048303e+07
#
#          is_trending  favoriteCount  chapter_count     card_count
# count  190915.000000       183454.0  186148.000000  186148.000000
# mean        0.182270            0.0       0.987827       0.027510
# std         0.386068            0.0       3.990665       0.163566
# min         0.000000            0.0       0.000000       0.000000
# 25%         0.000000            0.0       0.000000       0.000000
# 50%         0.000000            0.0       0.000000       0.000000
# 75%         0.000000            0.0       0.000000       0.000000
# max         1.000000            0.0     133.000000       1.000000

# %%
unique_videos.columns
# Out:
# Index(['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle',
#        'categoryId', 'trending_date', 'tags', 'view_count', 'likes',
#        'comment_count', 'thumbnail_link', 'description', 'is_trending',
#        'defaultLanguage', 'duration', 'dimension', 'definition', 'caption',
#        'licensedContent', 'projection', 'embeddable', 'madeForKids',
#        'favoriteCount', 'contentDetails.regionRestriction.blocked',
#        'contentDetails.regionRestriction.allowed',
#        'contentDetails.contentRating.ytRating', 'chapter_count', 'chapters',
#        'playability_status', 'supports_miniplayer', 'card_count', 'cards',
#        'is_verified', 'badge_labels', 'has_paid_promotion',
#        'comments_disabled'],
#       dtype='object')

# %% [markdown]
# # Accuracy

# %%
unique_videos = unique_videos[
    unique_videos["likes"] <= unique_videos["view_count"]
]

# %% [markdown]
# # Drop Unnecessary Columns

# %%
# thoughts: channelid : remove? replace with percentange?
new_df = unique_videos.drop(columns=["thumbnail_link", "chapters", "cards", "badge_labels","contentDetails.contentRating.ytRating","contentDetails.regionRestriction.allowed","contentDetails.regionRestriction.blocked","trending_date","favoriteCount"])

# %% [markdown]
# # Fix Columns

# %% [markdown]
# ## Tags to empty list

# %%
def process_tags(x):
    if isinstance(x, list):
        return x
    
    if pd.isna(x):
        return []
    
    if isinstance(x, str):
        x = x.strip()
        
        if x.startswith("[") and x.endswith("]"):
            x = x[1:-1]
        
        return [tag.strip() for tag in x.split(",") if tag.strip()]
    
    return []

new_df["tags"] = new_df["tags"].apply(process_tags)

# %%
new_df[new_df["tags"].apply(lambda x: x == [])]["tags"].count()
# Out:
# 71079

# %% [markdown]
# ## Description to empty string

# %%
new_df["description"] = new_df["description"].fillna("").astype(str)

# %%
new_df.isna().sum()
# Out:
# video_id                  0
# title                     0
# publishedAt               0
# channelId                 0
# channelTitle              0
# categoryId                0
# tags                      0
# view_count                0
# likes                     0
# comment_count            16
# description               0
# is_trending               0
# defaultLanguage        7258
# duration               7258
# dimension              7258
# definition             7258
# caption                7258
# licensedContent        7258
# projection             7258
# embeddable             7258
# madeForKids            7258
# chapter_count          4732
# playability_status     4732
# supports_miniplayer    4732
# card_count             4732
# is_verified            4732
# has_paid_promotion     4732
# comments_disabled        10
# dtype: int64

# %%
new_df[new_df["comment_count"].isna()]
# Out:
#            video_id                                              title  \
# 390093  2fgA7QQHyvA  عملنا لابنى سبوع كبير جدا 😳😳#شورتس #اكسبلور #c...
# 390261  mdJiUHRQUPM  Predictions 2026 World Cup 🏆🌍 #map #europe #ma...
# 390399  Acc8fNkcMnI  New design fancy silver Gold Rate Today #silve...
# 390442  970P0qLz02o                             #shorts #fürdich #vlog
# 390507  aIQNbHfoAiA  ഈ സർപ്രൈസ് കണ്ടപ്പോൾ ഒരുപാട് സന്തോഷം ❤️ #short...
# 390520  5dWOUf9DRAE                                          #reaction
# 390667  _wJ9TlA2UBc  Word Formation/Brain Test/innovative ideas #ed...
# 390685  5wA-YZ_CiuQ  How to use the Minecraft Education Support Center
# 390701  m85TOqMR5_A   #humor #comedia #viral #viralshort #soyfreddymar
# 390711  LGDFLg6dTSk  Kids don’t lie 🤣👶 #funny #Shorts #Kids #Viral ...
# 390731  yVrixLZeJfI  Paro ki chocolate churi 🫣😠#shortvideo #shortcl...
# 390739  fmWk3e76LQ0  couple comedy 😛😛 #shorts #funny #comedy #viral...
# 390864  -kK04LCp0vc  story asmaa beauty:حلم من احلامي تحقق ❤️شفوا ا...
# 390912  2F3P1NRupYY  🔴 Peppa Pig EN VIVO 🐷 Maratón Papá Pig 2026 🏃¡...
# 390943  VRRBHCyIIAE  Meals at the orphanage 🍲 #hope #minecraft #lov...
# 390983  eL_y-ZnXdFU      REDO: Google Ad Grants for Nonprofits in 2026
#
#                  publishedAt                 channelId  \
# 390520            NaN  ...  rectangular        True       False           0.0
# 390667            NaN  ...  rectangular        True       False           0.0
# 390685            NaN  ...  rectangular        True       False           0.0
# 390701            NaN  ...  rectangular        True       False           0.0
# 390711            NaN  ...  rectangular        True       False           0.0
# 390731            NaN  ...  rectangular        True       False           0.0
# 390739            NaN  ...  rectangular        True       False           0.0
# 390864            NaN  ...  rectangular        True       False           0.0
# 390912            NaN  ...  rectangular        True        True           0.0
# 390943            NaN  ...  rectangular        True       False           0.0
# 390983            NaN  ...  rectangular        True       False           0.0
#
#        playability_status supports_miniplayer card_count is_verified  \
# 390093         UNPLAYABLE                True        0.0       False
# 390261         UNPLAYABLE                True        0.0       False
# 390399         UNPLAYABLE                True        0.0       False
# 390442         UNPLAYABLE                True        0.0       False
# 390507         UNPLAYABLE                True        0.0       False
# 390520         UNPLAYABLE                True        0.0       False
# 390667         UNPLAYABLE                True        0.0       False
# 390685         UNPLAYABLE                True        0.0       False
# 390701         UNPLAYABLE                True        0.0       False
# 390711         UNPLAYABLE                True        0.0       False
# 390731         UNPLAYABLE                True        0.0       False
# 390739         UNPLAYABLE                True        0.0       False
# 390864         UNPLAYABLE                True        0.0       False
# 390912         UNPLAYABLE                True        0.0        True
# 390943         UNPLAYABLE                True        0.0       False
# 390983         UNPLAYABLE                True        0.0       False
#
#        has_paid_promotion comments_disabled
# 390093              False              True
# 390261              False             False
# 390399              False              True
# 390442              False              True
# 390507              False              True
# 390520              False              True
# 390667              False              True
# 390685              False              True
# 390701              False              True
# 390711              False              True
# 390731              False              True
# 390739              False              True
# 390864              False              True
# 390912              False              True
# 390943              False              True
# 390983              False              True
#
# [16 rows x 28 columns]

# %%
new_df[new_df["video_id"]=="mdJiUHRQUPM"]
# Out:
#            video_id                                              title  \
# 390261  mdJiUHRQUPM  Predictions 2026 World Cup 🏆🌍 #map #europe #ma...
#
#                  publishedAt                 channelId    channelTitle  \
# 390261  2026-04-06T16:15:43Z  UCK6Xt3WXrP4qtRlwq2wtmlg  Benjik52 Plays
#
#         categoryId tags  view_count  likes  comment_count  ...   projection  \
# 390261        27.0   []       602.0    7.0            0.0  ...  rectangular
#
#         embeddable madeForKids chapter_count playability_status  \
# 390261        True       False           0.0         UNPLAYABLE
#
#        supports_miniplayer card_count is_verified has_paid_promotion  \
# 390261                True        0.0       False              False
#
#        comments_disabled
# 390261             False
#
# [1 rows x 28 columns]

# %%
comments_disabled_bool = new_df["comments_disabled"].astype(bool)

new_df.loc[
    new_df["comment_count"].isna() & comments_disabled_bool,
    "comment_count"
] = 0

# %%
new_df.isna().sum()
# Out:
# video_id                  0
# title                     0
# publishedAt               0
# channelId                 0
# channelTitle              0
# categoryId                0
# tags                      0
# view_count                0
# likes                     0
# comment_count             0
# description               0
# is_trending               0
# defaultLanguage        7258
# duration               7258
# dimension              7258
# definition             7258
# caption                7258
# licensedContent        7258
# projection             7258
# embeddable             7258
# madeForKids            7258
# chapter_count          4732
# playability_status     4732
# supports_miniplayer    4732
# card_count             4732
# is_verified            4732
# has_paid_promotion     4732
# comments_disabled        10
# dtype: int64
